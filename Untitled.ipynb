# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import cv2

# %matplotlib inline
matplotlib.style.use('ggplot')

data_dir = './data'
data_csv = '/driving_log.csv'
model_json = 'model_behavioral_cloning_augmentation.json'
model_weights = 'model_behavioral_cloning_augmentation.h5'

#col_names = ['center', 'left','right','steering','throttle','brake','speed']
training_dat = pd.read_csv(data_dir+data_csv,names=None)
training_dat.head()
# Out:
#   C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarND-Behavioral-Cloning-P3-master\CarND-Behavioral-Cloning-P3-master\data\IMG\center_2019_09_01_18_27_50_468.jpg  \
# 0  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 1  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 2  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 3  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 4  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
#
#   C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarND-Behavioral-Cloning-P3-master\CarND-Behavioral-Cloning-P3-master\data\IMG\left_2019_09_01_18_27_50_468.jpg  \
# 0  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 1  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 2  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 3  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 4  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
#
#   C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarND-Behavioral-Cloning-P3-master\CarND-Behavioral-Cloning-P3-master\data\IMG\right_2019_09_01_18_27_50_468.jpg  \
# 0  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 1  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 2  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 3  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
# 4  C:\Users\Hiroyuki\CarND-Term1-Starter-Kit\CarN...
#
#      0  0.1  0.2  1.796362E-05
# 0  0.0  0.0  0.0      0.000019
# 1  0.0  0.0  0.0      0.000005
# 2  0.0  0.0  0.0      0.000003
# 3  0.0  0.0  0.0      0.000006
# 4  0.0  0.0  0.0      0.000006

# %%
# start with the center images only
X_train = training_dat['center']
X_left  = training_dat['left']
X_right = training_dat['right']
Y_train = training_dat['steering']
Y_train = Y_train.astype(np.float32)
if data_dir=='./data':
    X_train = X_train.apply(lambda x: data_dir+'/'+x)
X_train.head(),Y_train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow-cpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'center'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-8fda7f11002e> in <module>
#       1 # start with the center images only
# ----> 2 X_train = training_dat['center']
#       3 X_left  = training_dat['left']
#       4 X_right = training_dat['right']
#       5 Y_train = training_dat['steering']
#
# ~\Anaconda3\envs\tensorflow-cpu\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\envs\tensorflow-cpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'center'
